# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load Data
#
# In this lab, we are exploring crimes reported in Chicago in 2019. We will use this data to explore the context of logistic regression.

# %%
df = pd.read_csv("../data/chicago-crimes-2019.csv.gz", compression='gzip')
df.head(5)
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  11922110    JC547456  12/15/2019 03:40:00 AM      039XX W NORTH AVE  1020
# 1  11918688    JC543281  12/11/2019 01:20:00 PM    045XX S WESTERN AVE  5002
# 2  11896637    JC516819  11/19/2019 06:36:00 PM  012XX S SPAULDING AVE  031A
# 3  11845710    JC453753  09/30/2019 04:10:00 AM      048XX W CORTEZ ST  0265
# 4  11827810    JC432624  09/14/2019 01:25:00 AM   039XX W JACKSON BLVD  041A
#
#               Primary Type            Description  \
# 0                    ARSON                BY FIRE
# 1            OTHER OFFENSE  OTHER VEHICLE OFFENSE
# 2                  ROBBERY        ARMED - HANDGUN
# 3  CRIMINAL SEXUAL ASSAULT     AGGRAVATED - OTHER
# 4                  BATTERY   AGGRAVATED - HANDGUN
#
#                      Location Description  Arrest  Domestic  ...  Ward  \
# 0                  VEHICLE NON-COMMERCIAL   False     False  ...  26.0
# 1  PARKING LOT / GARAGE (NON RESIDENTIAL)    True     False  ...  15.0
# 2                                SIDEWALK   False     False  ...  24.0
# 3                               RESIDENCE    True      True  ...  37.0
# 4                                  STREET   False     False  ...  28.0
#
#    Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0            23.0        09     1149951.0    1910348.0  2019
# 1            61.0        26     1161131.0    1874302.0  2019
# 2            29.0        03     1154560.0    1894222.0  2019
# 3            25.0        02     1143935.0    1906545.0  2019
# 4            26.0       04B     1150182.0    1898397.0  2019
#
#                Updated On   Latitude  Longitude                       Location
# 0  04/27/2020 03:48:23 PM  41.909907 -87.724578  (41.909907002, -87.724577987)
# 1  04/27/2020 03:48:23 PM  41.810768 -87.684508  (41.810768138, -87.684507864)
# 2  04/27/2020 03:48:23 PM  41.865565 -87.708078  (41.865564662, -87.708077974)
# 3  04/27/2020 03:48:23 PM  41.899586 -87.746774   (41.89958619, -87.746774067)
# 4  04/27/2020 03:48:23 PM  41.877108 -87.724041  (41.877107715, -87.724041149)
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Feature Engineering
#
# First, we will clean up some features, and then create a new dataframe that has arrests and incidents by hour. From that data, we can compute arrest probability, as well as a time-shifted hour of the day, which seems to correlate better with the data.

# %%
df['Arrest'] = df['Arrest'].astype(int)
df['hour'] = pd.to_datetime(df['Date']).dt.hour

# %%
# Number of Arrests per hour
arrest_hour = pd.DataFrame(df.groupby(['hour'])['Arrest'] \
                                              .sum() \
                                              .reset_index(name='arrests') \
                                              .sort_values(['hour'], ascending=True))

# Number of Incidents per hour
all_hour = pd.DataFrame(df.groupby(['hour'])['ID'] \
                                              .count() \
                                              .reset_index(name='incidents') \
                                              .sort_values(['hour'], ascending=True))

# New Dataframe
adf = pd.merge(arrest_hour,all_hour,on=['hour'])
adf['prob'] = adf['arrests'] / adf['incidents']
adf
# Out:
#     hour  arrests  incidents      prob
# 0      0     2264      12467  0.181599
# 1      1     1769       7942  0.222740
# 2      2     1340       6922  0.193586
# 3      3      975       5481  0.177887
# 4      4      659       4407  0.149535
# 5      5      477       3827  0.124641
# 6      6      692       4408  0.156987
# 7      7      959       6174  0.155329
# 8      8     1448       8901  0.162678
# 9      9     1967      11524  0.170687
# 10    10     2609      11779  0.221496
# 11    11     2990      12158  0.245929
# 12    12     2873      15545  0.184818
# 13    13     2659      12508  0.212584
# 14    14     2671      13329  0.200390
# 15    15     2751      14394  0.191121
# 16    16     2958      14236  0.207783
# 17    17     3110      14422  0.215643
# 18    18     3501      14854  0.235694
# 19    19     4090      14822  0.275941
# 20    20     3571      13715  0.260372
# 21    21     3041      12432  0.244611
# 22    22     2936      12299  0.238719
# 23    23     2668      10454  0.255213

# %% [markdown]
# A look at this data shows that the probability of reported crimes resulting in arrest drops in the early morning hours (i.e., from 3-9 a.m.). We engineer some features based on this observation: (1) the probability of crimes resulting in arrest exceeding a threshold, and shifted hours of the day, that run 3 a.m. to 2:59 a.m.

# %%
# This is a derived binary variable that is "toy" for the sake of illustration.
adf['pthresh'] = adf['prob'] > 0.18
adf['hrs'] = (adf['hour'] + 21) % 24
adf
# Out:
#     hour  arrests  incidents      prob  pthresh  hrs
# 0      0     2264      12467  0.181599     True   21
# 1      1     1769       7942  0.222740     True   22
# 2      2     1340       6922  0.193586     True   23
# 3      3      975       5481  0.177887    False    0
# 4      4      659       4407  0.149535    False    1
# 5      5      477       3827  0.124641    False    2
# 6      6      692       4408  0.156987    False    3
# 7      7      959       6174  0.155329    False    4
# 8      8     1448       8901  0.162678    False    5
# 9      9     1967      11524  0.170687    False    6
# 10    10     2609      11779  0.221496     True    7
# 11    11     2990      12158  0.245929     True    8
# 12    12     2873      15545  0.184818     True    9
# 13    13     2659      12508  0.212584     True   10
# 14    14     2671      13329  0.200390     True   11
# 15    15     2751      14394  0.191121     True   12
# 16    16     2958      14236  0.207783     True   13
# 17    17     3110      14422  0.215643     True   14
# 18    18     3501      14854  0.235694     True   15
# 19    19     4090      14822  0.275941     True   16
# 20    20     3571      13715  0.260372     True   17
# 21    21     3041      12432  0.244611     True   18
# 22    22     2936      12299  0.238719     True   19
# 23    23     2668      10454  0.255213     True   20

# %% [markdown]
# ## Create Pipelines
#
# Below, we create the features for our model, and a pipeline for performing a logistic regression. We show a standard logistic regression, as well as one with cross-validation.

# %%
# Features for fitting the model.
x = adf['hrs'].astype('float').values.reshape(-1,1)
y = adf['pthresh']
z = np.arange(0.,24.,1).reshape(-1, 1);

# %%
penalty='l2'
C = 10
solver='lbfgs'

pipeline = Pipeline([
    ('norm', StandardScaler()),
    ('logr', LogisticRegression(penalty=penalty, 
                                C=C,
                                solver=solver))
])

pipelineCV = Pipeline([
    ('norm', StandardScaler()),
    ('logr', LogisticRegressionCV(penalty=penalty,
                                  class_weight='balanced',
                                  Cs=C,
                                  cv=3,
                                  random_state=0,
                                  solver=solver)),
])

# %% [markdown]
# ## Prediction

# %%
pipeline.fit(x,y)
line = pipeline.predict_proba(z)[:,1]

pipelineCV.fit(x,y)
lineCV = pipelineCV.predict_proba(z)[:,1]

hours = adf['hour'][3:].append(adf['hour'][0:3])
plt.xticks(np.arange(24),hours)
plt.xlabel('Hour')
plt.ylabel('Arrest?')
plt.plot(x,y,'.')
plt.plot(z, line, color='green')
plt.plot(z, lineCV, color='red')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Live Class Data Exploration

# %%
df['datetime'] = pd.to_datetime(df['Date'])

# %%
df['minute'] = df['datetime'].dt.hour * 60 + df['datetime'].dt.minute
df['second'] = df['minute'] * 60 + df['datetime'].dt.second
df
# Out:
#               ID Case Number                    Date                  Block  \
# 0       11922110    JC547456  12/15/2019 03:40:00 AM      039XX W NORTH AVE
# 1       11918688    JC543281  12/11/2019 01:20:00 PM    045XX S WESTERN AVE
# 2       11896637    JC516819  11/19/2019 06:36:00 PM  012XX S SPAULDING AVE
# 3       11845710    JC453753  09/30/2019 04:10:00 AM      048XX W CORTEZ ST
# 4       11827810    JC432624  09/14/2019 01:25:00 AM   039XX W JACKSON BLVD
# ...          ...         ...                     ...                    ...
# 258995     24550    JC270190  05/20/2019 01:13:00 AM  001XX N HERMITAGE AVE
# 258996     24551    JC271105  05/20/2019 06:07:00 PM       078XX S STATE ST
# 258997     24554    JC274572  05/23/2019 01:00:00 AM  069XX S MAPLEWOOD AVE
# 258998     24556    JC276141  05/24/2019 02:12:00 AM        013XX W 61ST ST
# 258999     24558    JC278685  05/25/2019 11:43:00 PM        004XX W 77TH ST
#
#         IUCR             Primary Type            Description  \
# 0       1020                    ARSON                BY FIRE
# 1       5002            OTHER OFFENSE  OTHER VEHICLE OFFENSE
# 2       031A                  ROBBERY        ARMED - HANDGUN
# 3       0265  CRIMINAL SEXUAL ASSAULT     AGGRAVATED - OTHER
# 4       041A                  BATTERY   AGGRAVATED - HANDGUN
# ...      ...                      ...                    ...
# 258995  0110                 HOMICIDE    FIRST DEGREE MURDER
# 258996  0110                 HOMICIDE    FIRST DEGREE MURDER
# 258997  0110                 HOMICIDE    FIRST DEGREE MURDER
# 258998  0110                 HOMICIDE    FIRST DEGREE MURDER
# 258999  0110                 HOMICIDE    FIRST DEGREE MURDER
#
#                           Location Description  Arrest  Domestic  ...  \
# 0                       VEHICLE NON-COMMERCIAL       0     False  ...
# 1       PARKING LOT / GARAGE (NON RESIDENTIAL)       1     False  ...
# 2                                     SIDEWALK       0     False  ...
# 3                                    RESIDENCE       1      True  ...
# 4                                       STREET       0     False  ...
# ...                                        ...     ...       ...  ...
# 258995                                  STREET       0     False  ...
# 258996                                  STREET       0     False  ...
# 258997                                   PORCH       0     False  ...
# 258998                                  GARAGE       0     False  ...
# 258999                                  STREET       0     False  ...
#
#         Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0          1910348.0  2019  04/27/2020 03:48:23 PM  41.909907 -87.724578
# 1          1874302.0  2019  04/27/2020 03:48:23 PM  41.810768 -87.684508
# 2          1894222.0  2019  04/27/2020 03:48:23 PM  41.865565 -87.708078
# 3          1906545.0  2019  04/27/2020 03:48:23 PM  41.899586 -87.746774
# 4          1898397.0  2019  04/27/2020 03:48:23 PM  41.877108 -87.724041
# ...              ...   ...                     ...        ...        ...
# 258995     1901279.0  2019  05/27/2019 04:12:56 PM  41.884721 -87.670624
# 258996     1852817.0  2019  05/27/2019 04:12:56 PM  41.751453 -87.624568
# 258997     1858532.0  2019  05/30/2019 04:12:42 PM  41.767505 -87.686989
# 258998     1864312.0  2019  05/31/2019 04:09:56 PM  41.783199 -87.657851
# 258999     1853877.0  2019  06/01/2019 04:04:59 PM  41.754424 -87.634786
#
#                              Location  hour            datetime minute  second
# 0       (41.909907002, -87.724577987)     3 2019-12-15 03:40:00    220   13200
# 1       (41.810768138, -87.684507864)    13 2019-12-11 13:20:00    800   48000
# 2       (41.865564662, -87.708077974)    18 2019-11-19 18:36:00   1116   66960
# 3        (41.89958619, -87.746774067)     4 2019-09-30 04:10:00    250   15000
# 4       (41.877107715, -87.724041149)     1 2019-09-14 01:25:00     85    5100
# ...                               ...   ...                 ...    ...     ...
# 258995  (41.884720804, -87.670624155)     1 2019-05-20 01:13:00     73    4380
# 258996  (41.751452878, -87.624567581)    18 2019-05-20 18:07:00   1087   65220
# 258997  (41.767504682, -87.686989416)     1 2019-05-23 01:00:00     60    3600
# 258998  (41.783199083, -87.657851361)     2 2019-05-24 02:12:00    132    7920
# 258999  (41.754424418, -87.634785654)    23 2019-05-25 23:43:00   1423   85380
#
# [259000 rows x 26 columns]

# %%
# Number of Arrests per hour
arrest_second = pd.DataFrame(df.groupby(['second'])['Arrest'] \
                                              .sum() \
                                              .reset_index(name='arrests') \
                                              .sort_values(['second'], ascending=True))

# Number of Incidents per hour
all_second = pd.DataFrame(df.groupby(['second'])['ID'] \
                                              .count() \
                                              .reset_index(name='incidents') \
                                              .sort_values(['second'], ascending=True))


# New Dataframe
adf2 = pd.merge(arrest_second,all_second,on=['second'])
adf2['prob'] = adf2['arrests'] / adf2['incidents']
adf2
# Out:
#       second  arrests  incidents      prob
# 0          0      150       3305  0.045386
# 1         60      102       2482  0.041096
# 2        120       38         94  0.404255
# 3        180       28         81  0.345679
# 4        240       31         65  0.476923
# ...      ...      ...        ...       ...
# 1609   86100       64        230  0.278261
# 1610   86160       24         52  0.461538
# 1611   86220       26         56  0.464286
# 1612   86280       42         91  0.461538
# 1613   86340       19        108  0.175926
#
# [1614 rows x 4 columns]

# %%
x = adf2['second']
y = adf2['prob'] > 0.18
plt.xlabel('Second')
plt.ylabel('Arrest?')
plt.plot(x,y,'.')
#plt.plot(z, line, color='green')
#plt.plot(z, lineCV, color='red')
plt.show()
